# %% [markdown]
# <a href="https://colab.research.google.com/github/salmaguillen/probable-computing-machine/blob/main/tarea_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np

# %%
path = '/content/drive/MyDrive/antropometria-dataset-2 (1).csv'

# %%
df = pd.read_csv(path)

# %%
df
# Out:
#         folio  intp  entidad                         desc_ent  sexo  edad  \
# 0      210295     2       21                           PUEBLA     2    38
# 1      101655     3       10                          DURANGO     2    11
# 2       10287     6        1                   AGUASCALIENTES     2    18
# 3       91526     4        9                 DISTRITO FEDERAL     1    10
# 4      210939     3       21                           PUEBLA     2    19
# ...       ...   ...      ...                              ...   ...   ...
# 18635  300116     2       30  VERACRUZ DE IGNACIO DE LA LLAVE     2    73
# 18636   40253     1        4                         CAMPECHE     2    75
# 18637  301099     1       30  VERACRUZ DE IGNACIO DE LA LLAVE     1    86
# 18638  250801     1       25                          SINALOA     2    72
# 18639   11786     2        1                   AGUASCALIENTES     2    71
#
#        meses   peso  ropa   talla  ... hpresion tbrazo  htension  PrimaryLast  \
# ...

# %%
estado = pd.pivot_table(df,
               index = ['desc_ent','sexo'],
               values = 'peso',
               aggfunc= ['mean'],
               margins = 'true')

# %%
# las mujeres pesan menos que los hombres, las muehreses en baja california pesan mas que en zacatecas

# %%
path2 = '/content/drive/MyDrive/adult.csv'

# %%
sf = pd.read_csv(path2)

# %%
sf
# Out:
#        age          workclass  fnlwgt   education  education-num  \
# 0       39          State-gov   77516   Bachelors             13
# 1       50   Self-emp-not-inc   83311   Bachelors             13
# 2       38            Private  215646     HS-grad              9
# 3       53            Private  234721        11th              7
# 4       28            Private  338409   Bachelors             13
# ...    ...                ...     ...         ...            ...
# 32559   22            Private  201490     HS-grad              9
# 32560   52       Self-emp-inc  287927     HS-grad              9
# 32561   52       Self-emp-inc  287927     HS-grad              9
# 32562   52       Self-emp-inc  287927     HS-grad              9
# 32563   52       Self-emp-inc  287927     HS-grad              9
#
#               marital-status          occupation    relationship    race  \
# 0              Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
sf.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'the label'],
#       dtype='object')

# %%
pd.pivot_table(sf,
               index = ['marital-status','sex','education'],
               values = 'age',
               aggfunc= 'median',
               margins = 'true')
# Out:
#                                               age
# marital-status        sex     education
#  Divorced              Female  10th          45.0
#                                11th          41.0
#                                12th          41.0
#                                1st-4th       64.0
#                                5th-6th       53.0
# ...                                           ...
#  Widowed               Male    Prof-school   42.5
#                                Some-college  60.5
#  test_category_female  Female  HS-grad       52.0
#  test_category_male    Male    HS-grad       52.0
# All                                          37.0
#
# [200 rows x 1 columns]

# %%
tabla = pd.pivot_table(sf,
               index = 'marital-status',
               values = 'age',
               aggfunc= 'count')
tabla
# Out:
#                           age
# marital-status
#  Divorced                4443
#  Married-AF-spouse         23
#  Married-civ-spouse     14976
#  Married-spouse-absent    418
#  Never-married          10683
#  Separated               1025
#  Widowed                  993
#  test_category_female       1
#  test_category_male         2

# %%
tabla['porcentaje']= (tabla['age'] /
                      tabla['age'].sum())* 100
tabla
# Out:
#                           age  porcentaje
# marital-status
#  Divorced                4443   13.643901
#  Married-AF-spouse         23    0.070630
#  Married-civ-spouse     14976   45.989436
#  Married-spouse-absent    418    1.283626
#  Never-married          10683   32.806166
#  Separated               1025    3.147648
#  Widowed                  993    3.049380
#  test_category_female       1    0.003071
#  test_category_male         2    0.006142

# %%
tabla
# Out:
#                           age  porcentaje
# marital-status
#  Divorced                4443   13.643901
#  Married-AF-spouse         23    0.070630
#  Married-civ-spouse     14976   45.989436
#  Married-spouse-absent    418    1.283626
#  Never-married          10683   32.806166
#  Separated               1025    3.147648
#  Widowed                  993    3.049380
#  test_category_female       1    0.003071
#  test_category_male         2    0.006142

# %%
tabla.head(3)
# Out:
#                        age  porcentaje
# marital-status
#  Divorced             4443   13.643901
#  Married-AF-spouse      23    0.070630
#  Married-civ-spouse  14976   45.989436

# %%
estado
# Out:
#                                mean
#                                peso
# desc_ent            sexo
# AGUASCALIENTES      1     69.985381
#                     2     63.254292
# BAJA CALIFORNIA     1     71.391818
#                     2     65.893667
# BAJA CALIFORNIA SUR 1     75.561015
# ...                             ...
# YUCATAN             1     65.717541
#                     2     60.537515
# ZACATECAS           1     66.096483
#                     2     62.757788
# All                       64.638707
#
# [65 rows x 1 columns]

# %%
d=pd.pivot_table(sf,
                 index = ['education','marital-status'],
                 values = ['age'])
d.head(70)
# Out:
#                                          age
# education  marital-status
#  10th       Divorced               44.133333
#             Married-civ-spouse     46.126074
#             Married-spouse-absent  42.000000
#             Never-married          23.961219
#             Separated              39.530612
# ...                                      ...
#  Doctorate  Married-spouse-absent  45.571429
#             Never-married          41.739726
#             Separated              42.857143
#             Widowed                65.000000
#  HS-grad    Divorced               42.363918
#
# [70 rows x 1 columns]

# %%
d
# Out:
#                                             age
# education     marital-status
#  10th          Divorced               44.133333
#                Married-civ-spouse     46.126074
#                Married-spouse-absent  42.000000
#                Never-married          23.961219
#                Separated              39.530612
# ...                                         ...
#  Some-college  Married-civ-spouse     42.210433
#                Married-spouse-absent  37.289474
#                Never-married          25.677804
#                Separated              38.086364
#                Widowed                57.523256
#
# [103 rows x 1 columns]
